# %% [markdown]
# # **Proyek Analisis Data**

# %% [markdown]
# ### Menyaipkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Gathering Data

# %%
customers_df = pd.read_csv('customers.csv')
customers_df.head()
# Out:
#    customer_id        customer_name       gender  age  \
# 0            1        Leanna Busson       Female   30
# 1            2  Zabrina Harrowsmith  Genderfluid   69
# 2            3      Shina Dullaghan   Polygender   59
# 3            4        Hewet McVitie     Bigender   67
# 4            5       Rubia Ashleigh   Polygender   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
orders_df = pd.read_csv('orders.csv')
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
products_df = pd.read_csv('products.csv')
products_df.head()
# Out:
#    product_ID product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
sales_df = pd.read_csv('sales.csv')
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2          212
# 1         1         1         481             118         1          118
# 2         2         1           2              96         3          288
# 3         3         1        1002             106         2          212
# 4         4         1         691             113         3          339

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# ### Menilai Data Customers

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1000 non-null   int64
#  1   customer_name  1000 non-null   object
#  2   gender         1000 non-null   object
#  3   age            1000 non-null   int64
#  4   home_address   1000 non-null   object
#  5   zip_code       1000 non-null   int64
#  6   city           1000 non-null   object
#  7   state          1000 non-null   object
#  8   country        1000 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.4+ KB

# %%
customers_df.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
print("Jumlah dupilkasi: ",customers_df.duplicated().sum())
# Out:
# Jumlah dupilkasi:  0

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1000.000000  1000.000000  1000.000000
# mean    500.500000    49.860000  5004.872000
# std     288.819436    17.647828  2884.497332
# min       1.000000    20.000000     2.000000
# 25%     250.750000    34.000000  2401.750000
# 50%     500.500000    50.000000  5083.000000
# 75%     750.250000    65.000000  7460.250000
# max    1000.000000    80.000000  9998.000000

# %% [markdown]
# ### Menilai Data Orders

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
orders_df.isna().sum()
# Out:
# order_id         0
# customer_id      0
# payment          0
# order_date       0
# delivery_date    0
# dtype: int64

# %%
print("Jumlah duplikasi: ",orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_df.describe()
# Out:
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# ### Menilai Data Produk

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_ID    1260 non-null   int64
#  1   product_type  1260 non-null   object
#  2   product_name  1260 non-null   object
#  3   size          1260 non-null   object
#  4   colour        1260 non-null   object
#  5   price         1260 non-null   int64
#  6   quantity      1260 non-null   int64
#  7   description   1260 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 78.9+ KB

# %%
products_df.isna().sum()
# Out:
# product_ID      0
# product_type    0
# product_name    0
# size            0
# colour          0
# price           0
# quantity        0
# description     0
# dtype: int64

# %%
print("Jumlah duplikasi: ",products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
products_df.describe()
# Out:
#         product_ID        price     quantity
# count  1260.000000  1260.000000  1260.000000
# mean    629.500000   105.805556    60.150000
# std     363.874979     9.704423    11.670573
# min       0.000000    90.000000    40.000000
# 25%     314.750000    95.750000    50.000000
# 50%     629.500000   108.500000    60.000000
# 75%     944.250000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %% [markdown]
# ### Menilai Data Sales

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     5000 non-null   int64
# dtypes: int64(6)
# memory usage: 234.5 KB

# %%
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",sales_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sales_df.describe()
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Duplicate Data

# %%
customers_df.duplicated().sum()
# Out:
# 0

# %%
customers_df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Missing values

# %%
customers_df.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
customers_df[customers_df.gender.isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, gender, age, home_address, zip_code, city, state, country]
# Index: []

# %%
customers_df.fillna(value="No Value",inplace=True)

# %%
customers_df.gender.value_counts()
# Out:
# gender
# Male           143
# Non-binary     131
# Polygender     128
# Genderqueer    127
# Genderfluid    122
# Bigender       120
# Female         115
# Agender        114
# Name: count, dtype: int64

# %% [markdown]
# ### Inaccurate value

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id        customer_name       gender  age  \
# 34            35     Adamo Saddington         Male   80
# 38            39      Legra Neaverson  Genderqueer   80
# 142          143      Hewitt Hanscome   Non-binary   80
# 154          155          Myrle Kelby         Male   80
# 170          171  Mariellen Medendorp      Agender   80
# 174          175        Patrica Penny   Non-binary   80
# 181          182        Ricardo James         Male   80
# 235          236       Anders Couvert   Non-binary   80
# 423          424     Katherine Sewter   Non-binary   80
# 437          438         Atlante Cure     Bigender   80
# 494          495         Darci Barten         Male   80
# 523          524      Beverlie Bansal      Agender   80
# 596          597           Hi Simenel  Genderfluid   80
# 701          702          Magda Dring   Non-binary   80
# 731          732         Gorden Seago  Genderfluid   80
#
#                           home_address  zip_code                   city  \
# 34   3168 Bartoletti CrescentSuite 878       593             Port Lucas
# 38     7440 Cameron Estate DrSuite 628      4622  North Victoriachester
# 142        87 Hahn Station StSuite 943      8254               New Ella
# 154           85 Charles MallSuite 424      7841            Port Sophia
# 170              16 Boyer WaySuite 018      6226          South Gabriel
# 174             57 David MallSuite 596      3129                Haneton
# 181           32 Thomas CrestSuite 753      2147             Archiefurt
# 235            64 Phillips RunApt. 722      2752            East Sienna
# 423            03 Grant CrestSuite 228      5743      Lake Charliemouth
# 437          569 Alyssa IslandApt. 766      6893             Hunterland
# 494          1798 Schultz MewsApt. 704      9409           Lake Caitlin
# 523            0358 Ashley WayApt. 506      3345     Port Sebastianland
# 596          78 O'hara CircuitApt. 096      1966       Lake Michaelbury
# 701              61 Bosco WaySuite 775       685        Thompsonborough
# 731    905 Stephanie BoulevardApt. 217      8114          Port Aaronton
#
#                   state    country
# 34           Queensland  Australia
# 38   Northern Territory  Australia
# 142            Victoria  Australia
# 154     New South Wales  Australia
# 170   Western Australia  Australia
# 174     South Australia  Australia
# 181          Queensland  Australia
# 235     New South Wales  Australia
# 423   Western Australia  Australia
# 437   Western Australia  Australia
# 494     New South Wales  Australia
# 523          Queensland  Australia
# 596     South Australia  Australia
# 701   Western Australia  Australia
# 731          Queensland  Australia

# %%
customers_df.age.replace(customers_df.age.max(),70,inplace=True)
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id      customer_name       gender  age  \
# 17            18      Chan Duchesne         Male   79
# 27            28      Hadley Baddam   Non-binary   79
# 47            48      Ronnie Shiril         Male   79
# 68            69     Tiphany Peacop     Bigender   79
# 73            74     Tracy Ebenezer  Genderqueer   79
# 151          152    Panchito Wybern       Female   79
# 209          210     Arden Lasselle   Polygender   79
# 211          212  Evelyn Chevolleau   Polygender   79
# 219          220    Francisca Accum     Bigender   79
# 303          304      Luke Salliere     Bigender   79
# 403          404         Teddy Gell   Non-binary   79
# 443          444        Sara Gelder   Polygender   79
# 559          560     Ritchie Cromly  Genderqueer   79
# 641          642   Beverley Yourell   Polygender   79
# 677          678       Dare Andrich      Agender   79
# 680          681      Shermy Mulbry   Polygender   79
# 698          699      Arlan Maffini  Genderqueer   79
# 743          744    Timmy Bullivent         Male   79
# 754          755       Herbert Rock       Female   79
# 805          806      Lonna Domange         Male   79
#
#                      home_address  zip_code               city  \
# 17        13 Bailey ManorApt. 848      7171         Walterland
# 27       360 Heller DriveApt. 052      5820          West Noah
# 47         78 Nguyen MallApt. 116      4761     Heathcotemouth
# 68         473 Leo CourtSuite 784      8820         East Sofia
# 73   3263 Parisian PlaceSuite 811      7803      West Jesseton
# 151       03 Glover TrackApt. 881      7845      Christianport
# 209    476 Mueller CrestSuite 674      5663  West Claudiaburgh
# 211    385 Jayden View RdApt. 459      4481         Port Logan
# 219         566 Kiara RunApt. 417      1993   West Zacharybury
# 303      5306 Hickle MewsApt. 405      7906        Feeneymouth
# 403       29 Bruen TrailSuite 288      9569      West Ellaport
# 443     361 Davies CrestSuite 392      6837     Port Andrewton
# 559   4674 Victoria DriveApt. 830      6122    Port Poppymouth
# 641      303 O'keefe PassApt. 658       192     North Benjamin
# 677    609 Rohan TerraceSuite 767      1948          East Alex
# 680      096 Gibson ManorApt. 195      1323     West Alyssaton
# 698       4959 James HillApt. 613      2027           Westfurt
# 743      440 Ernser GroveApt. 463      9828      East Zoeshire
# 754      04 Dare TerraceSuite 650      9976         West Aaron
# 805        865 Ivy TrailSuite 324      1265     New Joshuaview
#
#                             state    country
# 17                New South Wales  Australia
# 27                     Queensland  Australia
# 47                New South Wales  Australia
# 68                       Victoria  Australia
# 73             Northern Territory  Australia
# 151  Australian Capital Territory  Australia
# 209               New South Wales  Australia
# 211             Western Australia  Australia
# 219             Western Australia  Australia
# 303                    Queensland  Australia
# 403  Australian Capital Territory  Australia
# 443             Western Australia  Australia
# 559                    Queensland  Australia
# 641                      Tasmania  Australia
# 677               New South Wales  Australia
# 680                      Victoria  Australia
# 698             Western Australia  Australia
# 743            Northern Territory  Australia
# 754               New South Wales  Australia
# 805                      Tasmania  Australia

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1000.000000  1000.000000  1000.000000
# mean    500.500000    49.710000  5004.872000
# std     288.819436    17.431976  2884.497332
# min       1.000000    20.000000     2.000000
# 25%     250.750000    34.000000  2401.750000
# 50%     500.500000    50.000000  5083.000000
# 75%     750.250000    65.000000  7460.250000
# max    1000.000000    79.000000  9998.000000

# %% [markdown]
# ### Tipe Data

# %%
datetime_columns = ["order_date", "delivery_date"]
for colums in datetime_columns:
    orders_df[colums] = pd.to_datetime(orders_df[colums])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB
